# %% [markdown]
# # RH4.0 - UA & Sisqual
# ## Creating a calendar

# %% [markdown]
# <p>This is a notebook to to create a calendar associating each day in a
# given year with the most similar days in previous years.
# To find whether two days in different years are similar, temporal criteria
# and sales data are used.
# </p>
# <p>
#     The source datasets are...
# </p>

# %% [markdown]
# ### Read a dataset

# %%
import pandas as pd
pd.read_excel('tmp.xlsx', index_col=0)
